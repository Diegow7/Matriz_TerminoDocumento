# %% [markdown]
# # Taller 05: Herramientas para Indexación

# %% [markdown]
# **Objetivo:**
#
# Este ejercicio te permitirá recordar los conceptos fundamentales de indexación clásica en sistemas de recuperación de información. Implementarás un índice invertido manualmente y luego explorarás herramientas como *Whoosh* y *Elasticsearch* para construir y consular índices.

# %% [markdown]
# ### Parte 1: Construcción Manual de un Índice Invertido

# %% [markdown]
# **1. Cargar los datos en Python:**
#
# Usa pandas para cargar y explorar el dataset.

# %%
#Bibliotecas
import pandas as pd
import re
from collections import defaultdict

# %%
# Cargar dataset
data = pd.read_csv("../data/wiki_movie_plots_deduped.csv")
data = data[['Title', 'Plot']].dropna()  # Asegúrate de trabajar con campos no nulos
print(data.head())
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %% [markdown]
# **2. Construir un índice invertido:**
#
# Realiza una normalización básica del texto y posteriormente se genera el índice invertido.

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

data['Normalized_Plot'] = data['Plot'].apply(normalize_text)

# %%
inverted_index = defaultdict(list)

for idx, row in data.iterrows():
    tokens = row['Normalized_Plot'].split()
    for token in set(tokens):  # Evitar duplicados en un mismo documento
        inverted_index[token].append(row['Title'])

print(dict(list(inverted_index.items())[:10]))  # Muestra las primeras 10 entradas
# Out:
# {'breaking': ['Kansas Saloon Smashers', 'The Great Train Robbery', 'The Little Train Robbery', 'The Man Without a Country', 'The Cook', 'Out West', 'Neighbors', 'The Saphead', 'Slippy McGee', 'The White Sister', "Lady Windermere's Fan", 'Laugh, Clown, Laugh', 'Dangerous Curves', 'Hallelujah!', 'Honky Tonk', 'The Bishop Murder Case', 'The Dawn Patrol', 'Morocco', 'The Champ', 'The Criminal Code', 'Skippy', 'White Shoulders', 'Crooner', 'If I Had a Million', 'Partners', 'White Zombie', 'Duck Soup', 'Eskimo', 'I Cover the Waterfront', 'Mystery of the Wax Museum', 'She Done Him Wrong', 'Stage Mother', 'Too Much Harmony', 'Imitation of Life', 'What Every Woman Knows', 'Bride of Frankenstein', 'The Devil is a Woman', "Don't Bet on Blondes", 'The Man Who Broke the Bank at Monte Carlo', 'And So They Were Married', "Dracula's Daughter", 'Libeled Lady', 'Black Legion', 'Make Way for Tomorrow', 'Night Must Fall', 'Wells Fargo', 'Blond Cheat', 'Brother Rat', 'The Dawn Patrol', "The Devil's Party", 'Jezebel', 'Man-Proof', 'The Cowboy Quarterback', 'Intermezzo: A Love Story', 'The Lone Wolf Spy Hunt', 'Of Mice and Men', 'Thunder Afloat', 'Torchy Runs for Mayor', 'The Women', 'All This, and Heaven Too', 'Forty Little Mothers', 'He Married His Wife', 'No Census, No Feeling', "Sailor's Lady", "Saturday's Children", 'Tugboat Annie Sails Again', 'Two Girls on Broadway', 'Waterloo Bridge', 'Young Bill Hickok', 'Belle Starr', 'Man Hunt', 'So Long Mr. Chumps', 'That Uncertain Feeling', 'A Yank in the RAF', 'Eyes in the Night', 'Get Hep to Love', 'The Ghost of Frankenstein', 'Larceny, Inc.', 'Powder Town', 'Son of Fury: The Story of Benjamin Blake', 'The Spoilers', 'Wrecking Crew', 'The Constant Nymph', 'The Desperadoes', "The Gang's All Here", 'The Hard Way', 'Higher Than a Kite', "Sufferin' Cats!", 'Bathing Beauty', 'The Three Caballeros', 'Wilson', 'Hare Tonic', 'Micro-Phonies', 'The Picture of Dorian Gray', 'The Three Caballeros', 'The Beast with Five Fingers', 'Child of Divorce', 'Hair-Raising Hare', 'Racketeer Rabbit', 'The Three Troubledoers', 'Fun and Fancy Free', 'The Romance of Rosy Ridge', 'Adventures of Gallant Bess', 'Bodyguard', 'The Chicken of Tomorrow', 'Kitty Foiled', 'Professor Tom', 'The Truce Hurts', 'Up in Central Park', 'Champion', 'The Fountainhead', 'I Married a Communist', 'Johnny Stool Pigeon', 'Mr. Soft Touch', 'The Walking Hills', 'The Breaking Point', 'Mr. Music', 'Rabbit of Seville', 'Sierra', 'Vendetta', 'Jerry and Jumbo', 'The Model and the Marriage Broker', 'New Mexico', 'Pandora and the Flying Dutchman', 'The Thing from Another World', 'The Tooth Will Out', 'The Crimson Pirate', 'The Greatest Show on Earth', 'Push-Button Kitty', 'The Glass Wall', 'I Love Lucy', 'The Missing Mouse', 'Mouse for Sale', 'The Neanderthal Man', 'The Twonky', 'The Battle of Rogue River', 'Gorilla at Large', 'It Should Happen to You', 'Rear Window', 'The Steel Cage', 'Tobor the Great', 'Tight Spot', 'Wiretapper', 'D-Day the Sixth of June', 'Man in the Vault', 'Patterns', 'The Rack', 'Slightly Scarlet', 'The Ten Commandments', 'The Unguarded Moment', '3:10 to Yuma', 'The Big Caper', 'Monkey on My Back', 'The Monolith Monsters', 'The Unholy Wife', "What's Opera, Doc?", 'Fiend Without a Face', 'The Tunnel of Love', 'The Young Lions', "The Devil's Disciple", 'No Name on the Bullet', 'Sleeping Beauty', 'The Young Philadelphians', 'The Amazing Transparent Man', 'The Bellboy', 'Bells Are Ringing', 'Hell to Eternity', 'Spartacus', 'Visit to a Small Planet', 'El Cid', 'The Hustler', 'The Parent Trap', 'The Music Man', 'Six Black Horses', 'The Birds', 'The Haunted Palace', 'The Nutty Professor', 'The Carpetbaggers', 'The Collector', 'Faster, Pussycat! Kill! Kill!', 'The Hill', 'The Rounders', 'The Sound of Music', 'Blood Bath', 'A Funny Thing Happened on the Way to the Forum', 'Lost Command', 'The Russians Are Coming, the Russians Are Coming', "Who's Afraid of Virginia Woolf?", 'Billion Dollar Brain', 'Camelot', 'Caprice', 'Come Spy with Me', "Devil' ...

# %% [markdown]
# **3. Realizar consultas en el índice:**
#
# Implementa una función para buscar palabras clave.

# %%
def search_inverted_index(query, index):
    query = normalize_text(query)
    return index.get(query, [])

print(search_inverted_index("cyborg", inverted_index))
# Out:
# ['The Colossus of New York', 'Cyborg 2087', 'Spacehunter: Adventures in the Forbidden Zone', 'Superman III', 'Warrior of the Lost World', 'The Terminator', 'RoboCop', 'Cyborg', 'Moontrap', 'Nemesis', 'Cyborg 3: The Recycler', 'Cyborg Cop II', 'Space Truckers', 'Future War', 'Leprechaun 4: In Space', 'Virus', 'Jason X', 'Treasure Planet', 'Godzilla: Final Wars', 'Star Wars: Episode III – Revenge of the Sith', 'Tekken', 'Terminator Salvation', 'Justice League: The Flashpoint Paradox', 'Superman: Unbound', 'RoboCop', 'Hardcore Henry', 'Logan', 'Fortress', 'The Machine', 'Kill Command', 'April and the Extraordinary World', 'Sixty Million Dollar Man', 'Kung Fu Cyborg', 'Future X-Cops', 'Godzilla vs. Megalon', 'Kamen Rider V3', 'Kamen Rider V3 vs. the Destron Monsters', 'Terror of Mechagodzilla', 'JAKQ Dengeki Tai', 'JAKQ Dengeki Tai vs. Goranger', 'Sun Vulcan Movie', '964 Pinocchio', 'Zeiram', 'Tetsuo II: Body Hammer', 'Ghost in the Shell', 'Godzilla Against Mechagodzilla', 'Godzilla: Tokyo S.O.S.', 'Appleseed', 'Ghost in the Shell 2: Innocence', 'Godzilla: Final Wars', 'Kamen Rider the First', 'Appleseed Ex Machina : The Movie', 'Jūken Sentai Gekiranger: Nei-Nei! Hō-Hō! Hong Kong Great Deciding Match', 'Cyborg She', 'Redline', 'Tekken: Blood Vengeance', '009 Re:Cyborg', 'Blame!', 'Hardcore', 'Guardians', 'Cyborg She']

# %% [markdown]
# ### Parte 2: Usar Whoosh para Indexación y Recuperación

# %%
# !pip install whoosh
# Out:
# Collecting whoosh
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl.metadata (3.1 kB)
# Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#    ---------------------------------------- 0.0/468.8 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/468.8 kB 660.6 kB/s eta 0:00:01
#    ----- --------------------------------- 61.4/468.8 kB 656.4 kB/s eta 0:00:01
#    --------- ---------------------------- 122.9/468.8 kB 901.1 kB/s eta 0:00:01
#    --------------------- ------------------ 256.0/468.8 kB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 358.4/468.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 468.8/468.8 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: whoosh
# Successfully installed whoosh-2.7.4
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **1. Configuración del índice con Whoosh:**
#
# Define un esquema y configura el índice.

# %%
from whoosh.fields import Schema, TEXT
from whoosh.index import create_in
import os

schema = Schema(Title=TEXT(stored=True), Plot=TEXT(stored=True))

if not os.path.exists("index"):
    os.mkdir("index")
ix = create_in("index", schema)

# %% [markdown]
# **2. Agregar documentos al índice:**
#
# Agrega los títulos y tramas.

# %%
from whoosh.writing import AsyncWriter

writer = AsyncWriter(ix)
for _, row in data.iterrows():
    writer.add_document(Title=row['Title'], Plot=row['Plot'])
writer.commit()

# %% [markdown]
# **3. Realizar consultas:**
#
# Consulta palabras clave.

# %%
from whoosh.qparser import QueryParser

with ix.searcher() as searcher:
    query = QueryParser("Plot", ix.schema).parse("cyborg")
    results = searcher.search(query)
    for result in results:
        print(result['Title'])
# Out:
# Future War
# Space Truckers
# JAKQ Dengeki Tai
# JAKQ Dengeki Tai vs. Goranger
# Kung Fu Cyborg
# Future X-Cops
# Kamen Rider V3
# Kamen Rider V3 vs. the Destron Monsters
# Cyborg She
# Cyborg She

# %% [markdown]
# ### Parte 3: Usar Elasticsearch para Indexación y Recuperación

# %% [markdown]
# **1. Inicia Elasticsearch con Docker:**
#
# Configura e inicia un contenedor.

# %%
# !pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-8.17.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting elastic-transport<9,>=8.15.1 (from elasticsearch)
#   Downloading elastic_transport-8.17.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting urllib3<3,>=1.26.2 (from elastic-transport<9,>=8.15.1->elasticsearch)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi (from elastic-transport<9,>=8.15.1->elasticsearch)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Downloading elasticsearch-8.17.0-py3-none-any.whl (571 kB)
#    ---------------------------------------- 0.0/571.2 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/571.2 kB 1.4 MB/s eta 0:00:01
#    ------- -------------------------------- 112.6/571.2 kB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 225.3/571.2 kB 1.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 337.9/571.2 kB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 532.5/571.2 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 571.2/571.2 kB 2.1 MB/s eta 0:00:00
# Downloading elastic_transport-8.17.0-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.5 kB ? eta -:--:--
#    ---------------------------------------- 64.5/64.5 kB ? eta 0:00:00
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#    ---------------------------------------- 0.0/126.3 kB ? eta -:--:--
#    ---------------------------------------- 126.3/126.3 kB 7.3 MB/s eta 0:00:00
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    ---------------------------------------- 164.9/164.9 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: urllib3, certifi, elastic-transport, elasticsearch
# Successfully installed certifi-2024.12.14 elastic-transport-8.17.0 elasticsearch-8.17.0 urllib3-2.2.3
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **2. Configurar el cliente en Python:**
#
# Usa la librería elasticsearch.

# %%
from elasticsearch import Elasticsearch

# Conexión al servicio Elasticsearch sin autenticación básica
es = Elasticsearch(
    ['https://your-cluster-endpoint:443']  # Incluye el puerto
)

# Verificar que la conexión es exitosa
if es.ping():
    print("Conexión exitosa")
else:
    print("No se pudo conectar con Elasticsearch")
# Out:
# No se pudo conectar con Elasticsearch

# %%
import elasticsearch
print(elasticsearch.__version__)
# Out:
# (8, 17, 0)

# %% [markdown]
# **3. Indexar documentos:**
#
#
# Inserta películas en el índice.

# %%
for _, row in data.iterrows():
    doc = {'Title': row['Title'], 'Plot': row['Plot']}
    es.index(index='movies', body=doc)

# %% [markdown]
# **4.Realizar consultas:**
#
# Consulta con palabras clave.

# %%
query = {
    "query": {
        "match": {
            "Plot": "cyborg"
        }
    }
}
response = es.search(index='movies', body=query)
for hit in response['hits']['hits']:
    print(hit['_source']['Title'])
